# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder,OneHotEncoder

# %%
data={"color":["Red","Green","Yellow","Orange","Pink",]}
df=pd.DataFrame(data)
df
# Out:
#     color
# 0     Red
# 1   Green
# 2  Yellow
# 3  Orange
# 4    Pink

# %%
label_encoder=LabelEncoder()
df['Color_label']=label_encoder.fit_transform(df['color'])
df.head()
# Out:
#     color  Color_label
# 0     Red            3
# 1   Green            0
# 2  Yellow            4
# 3  Orange            1
# 4    Pink            2

# %%
one_hot_encoder=OneHotEncoder()
one_hot_encoded=one_hot_encoder.fit_transform(df[['color']])
one_hot_encoded_df=pd.DataFrame(one_hot_encoded.toarray(),columns=one_hot_encoder.get_feature_names_out())
df=pd.concat([df,one_hot_encoded_df],axis=1)
df
# Out:
#     color  Color_label  color_Green  color_Orange  color_Pink  color_Red  \
# 0     Red            3          0.0           0.0         0.0        1.0
# 1   Green            0          1.0           0.0         0.0        0.0
# 2  Yellow            4          0.0           0.0         0.0        0.0
# 3  Orange            1          0.0           1.0         0.0        0.0
# 4    Pink            2          0.0           0.0         1.0        0.0
#
#    color_Yellow
# 0           0.0
# 1           0.0
# 2           1.0
# 3           0.0
# 4           0.0
