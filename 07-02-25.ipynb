# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
import numpy as np

# %%
cars = pd.read_csv(r"C:\Users\KOUSHITHA KETHINENI\Downloads\Cars.csv")
cars.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
cars.shape
# Out:
# (81, 5)

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
cars.isna().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
cars.corr()
# Out:
#            HP       MPG       VOL        SP        WT
# HP   1.000000 -0.725038  0.077459  0.973848  0.076513
# MPG -0.725038  1.000000 -0.529057 -0.687125 -0.526759
# VOL  0.077459 -0.529057  1.000000  0.102170  0.999203
# SP   0.973848 -0.687125  0.102170  1.000000  0.102439
# WT   0.076513 -0.526759  0.999203  0.102439  1.000000

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(x=cars['WT'])
plt.title('Distribution of Weight of vehicles in Thousand Pounds')
plt.xlabel('Weight in Thousand Pounds')
plt.show()

# %%
sns.boxplot(x=cars['MPG'])
plt.show()

# %%
sns.boxplot(x=cars['HP'])
plt.show()

# %%
sns.boxplot(x=cars['SP'])
plt.show()

# %%
from seaborn import scatterplot
scatterplot(x=cars['VOL'],y=cars['MPG'])
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['SP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='SP', ylabel='MPG'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['HP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['WT'],y=cars['MPG'])
# Out:
# <Axes: xlabel='WT', ylabel='MPG'>

# %%
from seaborn import barplot
barplot(x=cars['SP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='SP', ylabel='MPG'>

# %%
from seaborn import barplot
barplot(x=cars['HP'],y=cars['MPG'])
# Out:
# <Axes: xlabel='HP', ylabel='MPG'>

# %%
from seaborn import barplot
barplot(x=cars['WT'],y=cars['MPG'])
# Out:
# <Axes: xlabel='WT', ylabel='MPG'>

# %%
from seaborn import barplot
barplot(x=cars['VOL'],y=cars['MPG'])
# Out:
# <Axes: xlabel='VOL', ylabel='MPG'>

# %%
sns.barplot(x=cars['SP'])
plt.show()

# %%
sns.barplot(x=cars['HP'])
plt.show()

# %%
sns.barplot(x=cars['WT'])
plt.show()

# %%
sns.barplot(x=cars['VOL'])
plt.show()

# %%
from seaborn import scatterplot
scatterplot(x=cars['HP'],y=cars['SP'])
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['HP'],y=cars['WT'])
# Out:
# <Axes: xlabel='HP', ylabel='WT'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['HP'],y=cars['VOL'])
# Out:
# <Axes: xlabel='HP', ylabel='VOL'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['WT'],y=cars['VOL'])
# Out:
# <Axes: xlabel='WT', ylabel='VOL'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['WT'],y=cars['SP'])
# Out:
# <Axes: xlabel='WT', ylabel='SP'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['VOL'],y=cars['SP'])
# Out:
# <Axes: xlabel='VOL', ylabel='SP'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['VOL'],y=cars['VOL'])
# Out:
# <Axes: xlabel='VOL', ylabel='VOL'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['SP'],y=cars['WT'])
# Out:
# <Axes: xlabel='SP', ylabel='WT'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['HP'],y=cars['HP'])
# Out:
# <Axes: xlabel='HP', ylabel='HP'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['WT'],y=cars['WT'])
# Out:
# <Axes: xlabel='WT', ylabel='WT'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['SP'],y=cars['SP'])
# Out:
# <Axes: xlabel='SP', ylabel='SP'>

# %%
from seaborn import scatterplot
scatterplot(x=cars['MPG'],y=cars['MPG'])
# Out:
# <Axes: xlabel='MPG', ylabel='MPG'>

# %%
from seaborn import barplot
barplot(x=cars['VOL'],y=cars['VOL'])
# Out:
# <Axes: xlabel='VOL', ylabel='VOL'>

# %%
from seaborn import barplot
barplot(x=cars['HP'],y=cars['HP'])
# Out:
# <Axes: xlabel='HP', ylabel='HP'>

# %%
from seaborn import barplot
barplot(x=cars['SP'],y=cars['SP'])
# Out:
# <Axes: xlabel='SP', ylabel='SP'>

# %%
from seaborn import barplot
barplot(x=cars['WT'],y=cars['WT'])
# Out:
# <Axes: xlabel='WT', ylabel='WT'>

# %%
from seaborn import barplot
barplot(x=cars['MPG'],y=cars['MPG'])
# Out:
# <Axes: xlabel='MPG', ylabel='MPG'>

# %%
from seaborn import boxplot
boxplot(x=cars['VOL'],y=cars['VOL'])
# Out:
# <Axes: xlabel='VOL', ylabel='VOL'>

# %%
from seaborn import boxplot
boxplot(x=cars['HP'],y=cars['SP'])
# Out:
# <Axes: xlabel='HP', ylabel='SP'>

# %%
from seaborn import boxplot
boxplot(x=cars['VOL'],y=cars['WT'])
# Out:
# <Axes: xlabel='VOL', ylabel='WT'>

# %%
from seaborn import boxplot
boxplot(x=cars['MPG'],y=cars['MPG'])
# Out:
# <Axes: xlabel='MPG', ylabel='MPG'>

# %%
from seaborn import boxplot
boxplot(x=cars['WT'],y=cars['WT'])
# Out:
# <Axes: xlabel='WT', ylabel='WT'>

# %%
from seaborn import boxplot
boxplot(x=cars['HP'],y=cars['HP'])
# Out:
# <Axes: xlabel='HP', ylabel='HP'>

# %%
cars.describe()
# Out:
#                HP        MPG         VOL          SP         WT
# count   81.000000  81.000000   81.000000   81.000000  81.000000
# mean   117.469136  34.422076   98.765432  121.540272  32.412577
# std     57.113502   9.131445   22.301497   14.181432   7.492813
# min     49.000000  12.101263   50.000000   99.564907  15.712859
# 25%     84.000000  27.856252   89.000000  113.829145  29.591768
# 50%    100.000000  35.152727  101.000000  118.208698  32.734518
# 75%    140.000000  39.531633  113.000000  126.404312  37.392524
# max    322.000000  53.700681  160.000000  169.598513  52.997752

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

cars[['HP','WT','VOL','SP']]=sc.fit_transform(cars[['HP','WT','VOL','SP']])

# %%
np.round(cars.describe(),3)
# Out:
#            HP     MPG     VOL      SP      WT
# count  81.000  81.000  81.000  81.000  81.000
# mean   -0.000  34.422   0.000   0.000   0.000
# std     1.006   9.131   1.006   1.006   1.006
# min    -1.206  12.101  -2.200  -1.559  -2.243
# 25%    -0.590  27.856  -0.441  -0.547  -0.379
# 50%    -0.308  35.153   0.101  -0.236   0.043
# 75%     0.397  39.532   0.642   0.345   0.669
# max     3.603  53.701   2.763   3.410   2.764

# %%
import statsmodels.formula.api as smf
ml_v=smf.ols('MPG~VOL',data = cars).fit()
ml_v.rsquared
# Out:
# 0.2799008651122705

# %%
ml_v.params
# Out:
# Intercept    34.422076
# VOL          -4.801137
# dtype: float64

# %%
ml_vol=smf.ols('MPG~VOL',data = cars).fit()
ml_vol.rsquared
# Out:
# 0.2799008651122705

# %%
ml_vol.params
# Out:
# Intercept    34.422076
# VOL          -4.801137
# dtype: float64

# %%
ml_w=smf.ols('MPG~WT',data = cars).fit()
ml_w.rsquared
# Out:
# 0.2774751389270127

# %%
ml_w.params
# Out:
# Intercept    34.422076
# WT           -4.780288
# dtype: float64

# %%
ml_w=smf.ols('MPG~SP',data = cars).fit()
ml_w.rsquared
# Out:
# 0.4721402334141217

# %%
ml_w.params
# Out:
# Intercept    34.422076
# HP           -6.579653
# dtype: float64

# %%
ml_w=smf.ols('MPG~HP',data = cars).fit()
ml_w.rsquared
# Out:
# 0.5256806086282022

# %%
ml_w.params
# Out:
# Intercept    34.422076
# HP           -6.579653
# dtype: float64

# %%
model = smf.ols('MPG~WT+VOL+SP+HP',data=cars).fit()

# %%
np.round(model.rsquared,2)
# Out:
# 0.77
